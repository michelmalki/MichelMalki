# %% [markdown]
# <a href="https://colab.research.google.com/github/michelmalki/MichelMalki/blob/main/house_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files
url = 'https://raw.githubusercontent.com/nabilbeit/McGill/main/Practical%20Statistics/house_sales.csv'
df = pd.read_csv(url)
print(df.head(5))
# Out:
#   DocumentDate\t"SalePrice"\t"PropertyID"\t"PropertyType"\t"ym"\t"zhvi_px"\t"zhvi_idx"\t"AdjSalePrice"\t"NbrLivingUnits"\t"SqFtLot"\t"SqFtTotLiving"\t"SqFtFinBasement"\t"Bathrooms"\t"Bedrooms"\t"BldgGrade"\t"YrBuilt"\t"YrRenovated"\t"TrafficNoise"\t"LandVal"\t"ImpsVal"\t"ZipCode"\t"NewConstruction"
# 0  1\t"2014-09-16"\t280000\t1000102\t"Multiplex"\...
# 1  2\t"2006-06-16"\t1000000\t1200013\t"Single Fam...
# 2  3\t"2007-01-29"\t745000\t1200019\t"Single Fami...
# 3  4\t"2008-02-25"\t425000\t2800016\t"Single Fami...
# 4  5\t"2013-03-29"\t240000\t2800024\t"Single Fami...

# %%
missing_values = df.isna()
null_values = df.isnull()
print(df[null_values])
print(df[missing_values])
print("\nData Types of Each Column:\n", df.dtypes)
# Out:
#       DocumentDate\t"SalePrice"\t"PropertyID"\t"PropertyType"\t"ym"\t"zhvi_px"\t"zhvi_idx"\t"AdjSalePrice"\t"NbrLivingUnits"\t"SqFtLot"\t"SqFtTotLiving"\t"SqFtFinBasement"\t"Bathrooms"\t"Bedrooms"\t"BldgGrade"\t"YrBuilt"\t"YrRenovated"\t"TrafficNoise"\t"LandVal"\t"ImpsVal"\t"ZipCode"\t"NewConstruction"
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 22682                                                NaN
# 22683                                                NaN
# 22684                                                NaN
# 22685                                                NaN
# 22686                                                NaN
#
# [22687 rows x 1 columns]
# ...

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("house_sales.csv")
df.head(100)
# Out:
#      <input type="file" id="files-e3806eac-ff5c-42a8-b1eb-16c88c6d1ab6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3806eac-ff5c-42a8-b1eb-16c88c6d1ab6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
missing_values = df.isna()
null_values = df.isnull()
print(df[null_values])
print(df[missing_values])
print("\nData Types of Each Column:\n", df.dtypes)
# Out:
#        id date  price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 1     NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 2     NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 3     NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 4     NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# ...    ..  ...    ...       ...        ...          ...       ...     ...
# 21608 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21609 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21610 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21611 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
# 21612 NaN  NaN    NaN       NaN        NaN          NaN       NaN     NaN
#
#        waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %%
import pandas as pd

df = pd.read_csv('house_sales.csv')
df['Country'] = 'Canada'
df.to_csv('updated_file.csv', index=False)
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900       3.0       1.00       1180.0
# 1  6414100192  20141209T000000  538000       3.0       2.25       2570.0
# 2  5631500400  20150225T000000  180000       2.0       1.00        770.0
# 3  2487200875  20141209T000000  604000       4.0       3.00       1960.0
# 4  1954400510  20150218T000000  510000       3.0       2.00       1680.0
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0    5650.0     1.0           0     0  ...        1180              0
# 1    7242.0     2.0           0     0  ...        2170            400
# 2   10000.0     1.0           0     0  ...         770              0
# 3    5000.0     1.0           0     0  ...        1050            910
# 4    8080.0     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
import matplotlib.pyplot as plt
df['price'].describe()
print(df['price'].describe())
plt.figure(figsize=(5, 3))
plt.hist(df['price'], bins = 25)
plt.title('Sale Price Distribution')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df['sqft_living'].describe()
print(df['sqft_living'].describe())
plt.figure(figsize=(5, 3))
plt.hist(df['sqft_living'], bins = 25)
plt.title('sqft_living Distribution')
plt.xlabel('sqft_living')
plt.ylabel('Density')
plt.show()
# Out:
# count    20503.000000
# mean      2081.073697
# std        915.043176
# min        290.000000
# 25%       1430.000000
# 50%       1920.000000
# 75%       2550.000000
# max      12050.000000
# Name: sqft_living, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df['bedrooms'].describe()
print(df['bedrooms'].describe())
plt.figure(figsize=(5, 3))
plt.hist(df['bedrooms'], bins = 25)
plt.title('bedrooms Distribution')
plt.xlabel('bedrooms')
plt.ylabel('Count')
plt.show()
# Out:
# count    20479.000000
# mean         3.372821
# std          0.930711
# min          0.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         33.000000
# Name: bedrooms, dtype: float64
