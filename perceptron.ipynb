# %% [markdown]
# <a href="https://colab.research.google.com/github/michelmalki/MichelMalki/blob/main/perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("1.csv")
df.head(10)
# Out:
#      <input type="file" id="files-d6b8af9d-4ba7-4c1e-ac7b-f5af72feaec0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6b8af9d-4ba7-4c1e-ac7b-f5af72feaec0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.describe()
# Out:
#               author        upvotes
# count  100142.000000  100142.000000
# mean    58405.758283      16.785824
# std     26610.838777      16.009816
# min     10104.000000       4.000000
# 25%     35499.000000      10.000000
# 50%     66298.000000      15.000000
# 75%     79598.000000      21.000000
# max     99532.000000     299.000000

# %%
labeled_df = df[df["label"] != "spam"]
print(labeled_df)
# Out:
#         author  upvotes label
# 1        92012       19  none
# 2        92012        9  none
# 3        92012       22  none
# 4        92012       18  none
# 5        92012       24  none
# ...        ...      ...   ...
# 100135   88566       16  none
# 100136   88566       17  none
# 100138   88566       23  none
# 100139   88566       22  none
# 100141   88566       25  none
#
# [89781 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
df_encoded = pd.get_dummies(df)
df_encoded.head()
# Out:
#    author  upvotes  label_good  label_none  label_spam
# 0   92012       11       False       False        True
# 1   92012       19       False        True       False
# 2   92012        9       False        True       False
# 3   92012       22       False        True       False
# 4   92012       18       False        True       False

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, confusion_matrix

data = labeled_df.drop(columns=["label", "upvotes"])
target = labeled_df["label"]

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

print(X_train)
print(y_train)
# Out:
#        author
# 99147   88566
# 5408    19499
# 45321   92169
# 3084    19499
# 53134   52948
# ...       ...
# 7009    21191
# 61346   82444
# 85623   40311
# 964     92012
# 17625   23347
#
# [71824 rows x 1 columns]
# 99147    none
# 5408     none
# 45321    none
# 3084     none
# 53134    none
#          ...
# 7009     good
# 61346    none
# 85623    none
# 964      none
# 17625    none
# Name: label, Length: 71824, dtype: object

# %%
perceptron = Perceptron(max_iter=900, random_state=42)
perceptron.fit(X_train, y_train)
# Out:
# Perceptron(max_iter=900, random_state=42)

# %%
predictor = perceptron.predict(X_test)
accuracy = accuracy_score(y_test, predictor)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9995544912847357

# %%
conf_matrix = confusion_matrix(y_test, predictor)
classification = classification_report(y_test, predictor)

# Print the confusion matrix and classification report
print("Confusion Matrix:", conf_matrix)

print("\nClassification Report:", classification)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Confusion Matrix: [[    0     8]
#  [    0 17949]]
#
# Classification Report:               precision    recall  f1-score   support
#
#         good       0.00      0.00      0.00         8
#         none       1.00      1.00      1.00     17949
#
#     accuracy                           1.00     17957
#    macro avg       0.50      0.50      0.50     17957
# ...

# %%
accuracy = (conf_matrix[0, 0] + conf_matrix[1, 1]) / conf_matrix.sum()
precision = conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[0, 1])
recall = conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[1, 0])
f1_score = 2 * (precision * recall) / (precision + recall)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall : {recall}")
print(f"F1-Score: {f1_score}")
# Out:
# Accuracy: 0.9995544912847357
# Precision: 0.0
# Recall : nan
# F1-Score: nan
# <ipython-input-38-2ea34a8aa0f8>:3: RuntimeWarning: invalid value encountered in scalar divide
#   recall = conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[1, 0])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y_test, predictor)
precision = precision_score(y_test, predictor,  pos_label='none')
recall = recall_score(y_test, predictor,  pos_label='none')
f1 = f1_score(y_test, predictor,  pos_label='none')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.9995544912847357
# Precision: 0.9995544912847357
# Recall: 1.0
# F1 Score: 0.9997771960118086
